# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanveer132/Regression-Types-in-Machine-Learning/blob/main/FST_LinearRegression_Bodyfat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Bodyfat.csv')
df
# Out:
#      Density  bodyfat  Age  Weight  Height  ...  Knee  Ankle  Biceps  Forearm  Wrist
# 0     1.0708     12.3   23  154.25   67.75  ...  37.3   21.9    32.0     27.4   17.1
# 1     1.0853      6.1   22  173.25   72.25  ...  37.3   23.4    30.5     28.9   18.2
# 2     1.0414     25.3   22  154.00   66.25  ...  38.9   24.0    28.8     25.2   16.6
# 3     1.0751     10.4   26  184.75   72.25  ...  37.3   22.8    32.4     29.4   18.2
# 4     1.0340     28.7   24  184.25   71.25  ...  42.2   24.0    32.2     27.7   17.7
# ..       ...      ...  ...     ...     ...  ...   ...    ...     ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  ...  34.8   21.5    25.6     25.7   18.5
# 248   1.0236     33.6   72  201.00   69.75  ...  40.8   23.2    35.2     28.6   20.1
# 249   1.0328     29.3   72  186.75   66.00  ...  37.3   21.5    31.3     27.2   18.0
# 250   1.0399     26.0   72  190.75   70.50  ...  41.6   22.7    30.5     29.4   19.8
# ...

# %%
sns.pairplot(data=df)

# %%
y=df['bodyfat']
df=df.drop(columns="bodyfat")
x=df
print(x)
print(y)
# Out:
#      Density  Age  Weight  Height  Neck  ...  Knee  Ankle  Biceps  Forearm  Wrist
# 0     1.0708   23  154.25   67.75  36.2  ...  37.3   21.9    32.0     27.4   17.1
# 1     1.0853   22  173.25   72.25  38.5  ...  37.3   23.4    30.5     28.9   18.2
# 2     1.0414   22  154.00   66.25  34.0  ...  38.9   24.0    28.8     25.2   16.6
# 3     1.0751   26  184.75   72.25  37.4  ...  37.3   22.8    32.4     29.4   18.2
# 4     1.0340   24  184.25   71.25  34.4  ...  42.2   24.0    32.2     27.7   17.7
# ..       ...  ...     ...     ...   ...  ...   ...    ...     ...      ...    ...
# 247   1.0736   70  134.25   67.00  34.9  ...  34.8   21.5    25.6     25.7   18.5
# 248   1.0236   72  201.00   69.75  40.9  ...  40.8   23.2    35.2     28.6   20.1
# 249   1.0328   72  186.75   66.00  38.9  ...  37.3   21.5    31.3     27.2   18.0
# 250   1.0399   72  190.75   70.50  38.9  ...  41.6   22.7    30.5     29.4   19.8
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2)
# print(x_train)
# print(y_train)
# print(x_test)

# %%
#prepare model
model=LinearRegression()
model.fit(x_train,y_train)
print(model.score(x_train,y_train))
# Out:
# 0.9744587493489084

# %%
plt.scatter(y_test,ypred,color='r')

# %%
error=y_test-ypred
print(error.mean())
# Out:
# -0.0891015752295509

# %%
#change the attributes of x
x1=df[['Density','Weight','Neck','Chest','Abdomen','Hip','Thigh']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y, test_size=0.2)

# %%
model.fit(x_train,y_train)
print(model.score(x_train,y_train))
print(model.coef_)
print(model.intercept_)
# Out:
# 0.9722595343708911
# [-4.04894233e+02 -1.20771285e-03 -3.53707022e-02  3.65756146e-02
#   5.21595235e-02  1.32863961e-02 -4.19102761e-02]
# 440.7909688554509

# %%
y_pred=model.predict(x_test)

# %%
error=y_test-y_pred
print(error.mean())
# Out:
# -0.1856285062821351

# %%
print(model.coef_)
pd.DataFrame(model.coef_,x1.columns,columns=['Coef'])
# Out:
# [-4.04894233e+02 -1.20771285e-03 -3.53707022e-02  3.65756146e-02
#   5.21595235e-02  1.32863961e-02 -4.19102761e-02]
#                Coef
# Density -404.894233
# Weight    -0.001208
# Neck      -0.035371
# Chest      0.036576
# Abdomen    0.052160
# Hip        0.013286
# Thigh     -0.041910

# %% [markdown]
# With normalized data

# %%
df=pd.read_csv('/content/Bodyfat.csv')
df
# Out:
#      Density  bodyfat  Age  Weight  Height  ...  Knee  Ankle  Biceps  Forearm  Wrist
# 0     1.0708     12.3   23  154.25   67.75  ...  37.3   21.9    32.0     27.4   17.1
# 1     1.0853      6.1   22  173.25   72.25  ...  37.3   23.4    30.5     28.9   18.2
# 2     1.0414     25.3   22  154.00   66.25  ...  38.9   24.0    28.8     25.2   16.6
# 3     1.0751     10.4   26  184.75   72.25  ...  37.3   22.8    32.4     29.4   18.2
# 4     1.0340     28.7   24  184.25   71.25  ...  42.2   24.0    32.2     27.7   17.7
# ..       ...      ...  ...     ...     ...  ...   ...    ...     ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  ...  34.8   21.5    25.6     25.7   18.5
# 248   1.0236     33.6   72  201.00   69.75  ...  40.8   23.2    35.2     28.6   20.1
# 249   1.0328     29.3   72  186.75   66.00  ...  37.3   21.5    31.3     27.2   18.0
# 250   1.0399     26.0   72  190.75   70.50  ...  41.6   22.7    30.5     29.4   19.8
# ...

# %%
x1=df[['Density','Weight','Neck','Chest','Abdomen','Hip','Thigh']]
x1.head()
# Out:
#    Density  Weight  Neck  Chest  Abdomen    Hip  Thigh
# 0   1.0708  154.25  36.2   93.1     85.2   94.5   59.0
# 1   1.0853  173.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414  154.00  34.0   95.8     87.9   99.2   59.6
# 3   1.0751  184.75  37.4  101.8     86.4  101.2   60.1
# 4   1.0340  184.25  34.4   97.3    100.0  101.9   63.2

# %%
m=MinMaxScaler()    
m.fit(x1)
x_norm=m.transform(x1)
#x_norm=pd.DataFrame(x_norm)

# %%
sns.boxplot(data=x_norm)
plt.show()

# %%
y=df[["bodyfat"]]
m=MinMaxScaler()    
m.fit(y)
y_norm=m.transform(y)

# %%
sns.boxplot(data=y_norm)
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x_norm,y_norm, test_size=0.2)

# %%
model1=LinearRegression()
model1.fit(x_train,y_train)
print(model1.score(x_train,y_train))
print(model1.coef_)
print(model1.intercept_)
# Out:
# 0.9776567069448945
# [[-0.9854235  -0.01301108 -0.00428724  0.03512246  0.06990395  0.03055609
#   -0.03839169]]
# [0.90249011]

# %%
y_pred=model.predict(x_test)

# %%
error=y_pred-y_test
print(error)
# Out:
# [[ 8.43910508e-05]
#  [ 3.65800736e-03]
#  [ 3.81305707e-03]
#  [-8.59772699e-03]
#  [-5.41487506e-03]
#  [-2.28569152e-02]
#  [-6.08431197e-03]
#  [-4.31504582e-03]
#  [ 5.10465039e-03]
#  [-1.21272098e-02]
#  [ 1.04667357e-02]
#  [ 1.07148898e-02]
#  [ 5.33771361e-03]
#  [ 2.65744128e-03]
#  [ 7.37923531e-04]
#  [ 5.91483040e-04]
#  [ 1.67753639e-03]
#  [ 8.35543526e-03]
#  [ 2.12723797e-04]
#  [-1.10480063e-02]
#  [ 6.21810625e-03]
#  [ 6.03272945e-04]
#  [ 6.11729841e-03]
#  [ 8.47435775e-03]
#  [ 1.03038079e-02]
#  [-6.54756462e-04]
#  [-1.24191206e-02]
#  [-4.85902792e-03]
#  [-5.82277457e-03]
#  [-1.42401053e-02]
#  [ 3.93393939e-03]
#  [-7.40062067e-03]
#  [ 2.43905954e-03]
#  [ 1.21335313e-02]
#  [-1.51271752e-03]
#  [ 1.97685209e-04]
#  [-1.30332319e-03]
#  [-1.41087693e-02]
#  [-7.75448206e-03]
#  [-7.70631710e-03]
#  [-4.82540927e-03]
#  [ 2.18261506e-02]
#  [ 6.23679987e-03]
#  [ 1.90570926e-02]
#  [ 6.54343091e-03]
#  [-2.09440595e-03]
#  [ 1.02109802e-02]
# ...

# %%
sns.histplot(error,kde=True)
